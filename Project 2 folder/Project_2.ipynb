# %%
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
file_path = Path("AUD_exchange_rate.csv")
df_exchange_rates = pd.read_csv(file_path)

file_path_1 = Path("cash_rate_aus_10y.csv")
df_cash_rate = pd.read_csv(file_path_1)

file_path_2 = Path("CPI_aus_10y.csv")
df_CPI = pd.read_csv(file_path_2)

file_path_3 = Path("historical_GDP_data.csv")
df_gdp = pd.read_csv(file_path_3)

file_path_4 = Path("dpie_nsw_sydney_approvals_monthly.csv")
df_gdp = pd.read_csv(file_path_4)

df_cash_rate.head()
# Out:
#   F1 INTEREST RATES AND YIELDS � MONEY MARKET                Unnamed: 1  \
# 0                                       Title          Cash Rate Target
# 1                                 Description  Cash Rate Target on date
# 2                                   Frequency                     Daily
# 3                                        Type                  Original
# 4                                       Units                  Per cent
#
#                                           Unnamed: 2  \
# 0                    Change in the Cash Rate Target
# 1  Change in the Cash Rate Target (in percentage ...
# 2                                       as announced
# 3                                           Original
# 4                                           Per cent
#
#                               Unnamed: 3  \
# 0          Interbank Overnight Cash Rate
# 1  Interbank Overnight Cash Rate on date
# 2                                  Daily
# 3                               Original
# 4                               Per cent
#
#                                       Unnamed: 4  \
# 0          Highest Interbank Overnight Cash Rate
# 1  Highest Interbank Overnight Cash Rate on date
# 2                                          Daily
# 3                                       Original
# 4                                       Per cent
#
#                                      Unnamed: 5  \
# 0          Lowest Interbank Overnight Cash Rate
# 1  Lowest Interbank Overnight Cash Rate on date
# 2                                         Daily
# 3                                      Original
# 4                                      Per cent
#
#                                           Unnamed: 6  \
# 0                 Volume of Cash Market Transactions
# 1  Volume of Interbank Overnight Cash Market Tran...
# 2                                              Daily
# 3                                           Original
# 4                                                 $m
#
#                                           Unnamed: 7  \
# 0                 Number of Cash Market Transactions
# 1  Number of Interbank Overnight Cash Market Tran...
# 2                                              Daily
# 3                                           Original
# 4                                            Number
#
#                              Unnamed: 8  \
# 0                    Total Return Index
# 1  Cash Rate Total Return Index on date
# 2                                 Daily
# 3                              Original
# 4                 Index 04-Jan-2011=100
#
#                                           Unnamed: 9  \
# 0                              EOD 1-month BABs/NCDs
# 1  Bank Accepted Bills/Negotiable Certificates of...
# 2                                              Daily
# 3                                           Original
# 4                                           Per cent
#
#                                          Unnamed: 10  \
# 0                              EOD 3-month BABs/NCDs
# 1  Bank Accepted Bills/Negotiable Certificates of...
# 2                                              Daily
# 3                                           Original
# 4                                           Per cent
#
#                                          Unnamed: 11  \
# 0                              EOD 6-month BABs/NCDs
# 1  Bank Accepted Bills/Negotiable Certificates of...
# 2                                              Daily
# 3                                           Original
# 4                                           Per cent
#
#                        Unnamed: 12                       Unnamed: 13  \
# 0                      1-month OIS                       3-month OIS
# 1  Overnight Indexed Swaps-1 month  Overnight Indexed Swaps-3 months
# 2                            Daily                             Daily
# 3                         Original                          Original
# 4                         Per cent                          Per cent
#
#                         Unnamed: 14            Unnamed: 15  \
# 0                       6-month OIS  1-month Treasury Note
# 1  Overnight Indexed Swaps-6 months  Treasury Note-1 month
# 2                             Daily                  Daily
# 3                          Original               Original
# 4                          Per cent               Per cent
#
#               Unnamed: 16             Unnamed: 17  Unnamed: 18
# 0  3- month Treasury Note  6- month Treasury Note          NaN
# 1   Treasury Note-3 month   Treasury Note-6 month          NaN
# 2                   Daily                   Daily          NaN
# 3                Original                Original          NaN
# 4                Per cent                Per cent          NaN

# %%
# Need to clean the data, and concatinate the data frames. 
# From cash rate we need the second column. 
#DPIE we need the Grand Total. 
# AUD exhange rate will use USD which is the first column.
# Will use the sydney CPI data from the CPI df, and its the first column of data (after the date)
# Will use the percentage change in GDP, which is the third column in the dataframe

# %%
# Define features set
X = df_loans.copy()
X.drop("Default", axis=1, inplace=True)
X.head()
